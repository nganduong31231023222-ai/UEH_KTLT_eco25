# %% [markdown]
# <a href="https://colab.research.google.com/github/nganduong31231023222-ai/UEH_KTLT_eco25/blob/buoi2/Bai_tap_mau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Whoever is happy will make others happy too")
print("--Anne Frank")
# Out:
# Whoever is happy will make others happy too
# --Anne Frank

# %%
# Nhập dữ liệu
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))
# Xử lý
kqCong = a + b
kqTru = a - b
kqNhan = a * b
kqChiaNguyen = a // b
kqDu= a % b
kqChiaThuc = a / b
# Xuất dữ liệu
print("Cac ket qua tinh toan: ")
print("%-5d + %5d = %5d"%(a, b, kqCong))
print("%-5d - %5d = %5d"%(a, b, kqTru))
print("%-5d * %5d = %5d"%(a, b, kqNhan))
print("%-5d / %5d = %5d"%(a, b, kqChiaNguyen))
print("%-5d / %5d = %5d"%(a, b, kqDu))
print("%-5d / %5d = %5.2f"%(a, b, kqChiaThuc))
# Out:
# Moi ban nhap so a: 5
# Moi ban nhap so b: 6
# Cac ket qua tinh toan:
# 5     +     6 =    11
# 5     -     6 =    -1
# 5     *     6 =    30
# 5     /     6 =     0
# 5     /     6 =     5
# 5     /     6 =  0.83

# %%
# Nhập dữ liệu
a = float(input("Moi ban nhap so a: "))
b = float(input("Moi ban nhap so b: "))
# Xử lý
laNhoHon = (a < b)
laNhoHonBang = (a <= b)
laLonHon = (a > b)
laLonHonBang = (a >= b)
laBang = (a == b)
laKhacNhau = (a != b)
# Xuất dữ liệu
print("Ket qua so sanh hai so thuc %.2f va %.2f:"%(a, b))
print("%-8.2f < %8.2f: %8s"%(a, b, laNhoHon))
print("%-8.2f <= %8.2f: %8s"%(a, b, laNhoHonBang))
print("%-8.2f > %8.2f: %8s"%(a, b, laLonHon))
print("%-8.2f >= %8.2f: %8s"%(a, b, laLonHonBang))
print("%-8.2f == %8.2f: %8s"%(a, b, laBang))
print("%-8.2f != %8.2f: %8s"%(a, b, laKhacNhau))
# Out:
# Moi ban nhap so a: 2.5
# Moi ban nhap so b: 6.8
# Ket qua so sanh hai so thuc 2.50 va 6.80:
# 2.50     <     6.80:     True
# 2.50     <=     6.80:     True
# 2.50     >     6.80:    False
# 2.50     >=     6.80:    False
# 2.50     ==     6.80:    False
# 2.50     !=     6.80:     True

# %%
# Nạp thư viện
import math
# Nhập dữ liệu
x = float(input("Moi ban nhap vao gia tri cua bien so x: "))
# Xử lý
fx = x + math.pow(x, 5) / (1 * 2 * 3 * 4 * 5) + \
math.sqrt(abs(x)) / math.pow(x, 3.0 / 2)
# Xuất dữ liệu
print("Gia tri cua ham so f(%.2f) = %.2f."%(x, fx))
# Out:
# Moi ban nhap vao gia tri cua bien so x: 2.3
# Gia tri cua ham so f(2.30) = 3.27.

# %%
def tong_chu_so_4_chu_so(n: int) -> int:
    if not (1000 <= abs(n) <= 9999):
        raise ValueError("Vui lòng nhập số nguyên có đúng 4 chữ số (ví dụ: 1234 hoặc -5678).")
    n_abs = abs(n)
    s = 0
    while n_abs > 0:
        s += n_abs % 10
        n_abs //= 10
    return s

# Chạy tương tác
try:
    n = int(input("Mời bạn nhập số nguyên n (có bốn chữ số): "))
    kq = tong_chu_so_4_chu_so(n)
    n_abs = abs(n)
    d4 = n_abs // 1000
    d3 = (n_abs // 100) % 10
    d2 = (n_abs // 10) % 10
    d1 = n_abs % 10
    print(f"{n} = {d4} + {d3} + {d2} + {d1} = {kq}")
except ValueError as e:
    print(e)
# Out:
# Mời bạn nhập số nguyên n (có bốn chữ số): 1234
# 1234 = 1 + 2 + 3 + 4 = 10
